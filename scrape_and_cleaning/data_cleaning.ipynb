# %% [markdown]
# # i. Introduction

# %% [markdown]
# Program ini dikembangkan untuk melakukan tahapan data cleaning dan preprocessing pada dataset hasil web scraping produk __TWS__ dari E-Commerce __Amazon__. Tahapan yang dilakukan mencakup normalisasi nama kolom, imputasi missing values sesuai dengan tipe data, konversi tipe data kolom _price_ dan _rating_ ke format numerik, serta ekstraksi informasi fitur produk ke dalam kolom __feature__ melalui pemisahan teks pada kolom __product_name__.
#
# Tahapan data cleaning ini bertujuan untuk memastikan data memiliki kualitas yang baik, konsistensi format, serta kompatibilitas terhadap proses analisis statistik dan pemodelan data selanjutnya.

# %% [markdown]
# # ii. Import Libraries

# %%
# Import Libraries
import json
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # iii. Data Loading

# %%
#read json file
with open('soundcore.json') as f1, open('bose.json') as f2, open('baseus.json') as f3, open('jbl.json') as f4, open('sennheiser.json') as f5, open('realme.json') as f6, open('huawei.json') as f7, open('samsung.json') as f8, open('xiaomi.json') as f9:
    data1 = json.load(f1)
    data2 = json.load(f2)
    data3 = json.load(f3)
    data4 = json.load(f4)
    data5 = json.load(f5)
    data6 = json.load(f6)
    data7 = json.load(f7)
    data8 = json.load(f8)
    data9 = json.load(f9)

#combine all data
data = data1 + data2 + data3 + data4 + data5 + data6 + data7 + data8 + data9

#save combined data to json file
with open("all_data.json", "w") as review_json:
    json.dump(data, review_json, indent=2, ensure_ascii=True)

# %%
# Read JSON file into DataFrame
with open('all_data.json') as f:
    data = json.load(f)

df = pd.DataFrame(data)
df
# Out:
#                                           product_name              rating  \
# 0    Soundcore P30i by Anker Noise Cancelling Earbu...  4.4 out of 5 stars
# 1    Soundcore P30i by Anker Noise Cancelling Earbu...  4.4 out of 5 stars
# 2    Soundcore P30i by Anker Noise Cancelling Earbu...  4.4 out of 5 stars
# 3    Soundcore P30i by Anker Noise Cancelling Earbu...  4.4 out of 5 stars
# 4    Soundcore P30i by Anker Noise Cancelling Earbu...  4.4 out of 5 stars
# ..                                                 ...                 ...
# 718  JBL Tune Buds - True wireless Noise Cancelling...  4.2 out of 5 stars
# 719  realme Air 6 Pro True Wireless Earbuds, 50dB N...  4.4 out of 5 stars
# 720  realme Air 6 Pro True Wireless Earbuds, 50dB N...  4.4 out of 5 stars
# 721  realme Buds Air 6 Pro True Wireless Earbuds, 5...  4.4 out of 5 stars
# 722  Soundcore P40i by Anker, Noise Cancelling Wire...  4.3 out of 5 stars
#
#       price      brand        color ear_placement form_factor impedance  \
# 0    $29.99  Soundcore        Black        In Ear      In Ear   16 Ohms
# 1    $29.99  Soundcore        Black        In Ear      In Ear   16 Ohms
# 2     $7.79  Soundcore         Blue        In Ear      In Ear   16 Ohms
# 3     $7.59  Soundcore        Green        In Ear      In Ear   16 Ohms
# 4    $29.99  Soundcore         Pink        In Ear      In Ear   16 Ohms
# ..      ...        ...          ...           ...         ...       ...
# 718  $59.95        JBL        Black        In Ear      In Ear   32 Ohms
# 719  $87.82     realme         Grey        In Ear      In Ear       N/A
# 720  $87.82     realme         Grey        In Ear      In Ear       N/A
# 721  $84.99     realme  Silver Blue        In Ear      In Ear  1.4 Ohms
# 722  $34.99  Soundcore        Black        In Ear      In Ear   14 Ohms
#
#                                              image_url  \
# 0    https://m.media-amazon.com/images/I/51HbL1WS+K...
# 1    https://m.media-amazon.com/images/I/51HbL1WS+K...
# 2    https://m.media-amazon.com/images/I/41Quiz3Dg-...
# 3    https://m.media-amazon.com/images/I/51013C6va8...
# 4    https://m.media-amazon.com/images/I/41KMo8Ldy8...
# ..                                                 ...
# 718  https://m.media-amazon.com/images/I/51EZig0rEA...
# 719  https://m.media-amazon.com/images/I/61Ktz5wyEw...
# 720  https://m.media-amazon.com/images/I/61Ktz5wyEw...
# 721  https://m.media-amazon.com/images/I/61e3G6oLxj...
# 722  https://m.media-amazon.com/images/I/61e9Npl3up...
#
#                                                reviews
# 0    [{'review': 'I had a pair of the AirPod Pros f...
# 1    [{'review': 'I had a pair of the AirPod Pros f...
# 2    [{'review': 'I had a pair of the AirPod Pros f...
# 3    [{'review': 'I had a pair of the AirPod Pros f...
# 4    [{'review': 'I had a pair of the AirPod Pros f...
# ..                                                 ...
# 718  [{'review': 'Very comfortable, decent noise ca...
# 719  [{'review': 'ConThe only bad part about these ...
# 720  [{'review': 'ConThe only bad part about these ...
# 721  [{'review': 'Amazing sound. The app was wonky ...
# 722  [{'review': 'I got these as a lower-cost repla...
#
# [723 rows x 10 columns]

# %%
# Save to CSV as backup
df.to_csv('data_before_clean.csv', index=False)

# %%
# Display DataFrame info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 723 entries, 0 to 722
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_name   723 non-null    object
#  1   rating         723 non-null    object
#  2   price          723 non-null    object
#  3   brand          723 non-null    object
#  4   color          723 non-null    object
#  5   ear_placement  723 non-null    object
#  6   form_factor    723 non-null    object
#  7   impedance      723 non-null    object
#  8   image_url      723 non-null    object
#  9   reviews        723 non-null    object
# dtypes: object(10)
# memory usage: 56.6+ KB

# %% [markdown]
# # iii. Data Cleaning

# %%
# Check for duplicate product names
df['product_name'].duplicated().sum()
# Out:
# 430

# %%
# Remove duplicate product names
df = df.drop_duplicates(subset='product_name')

# %%
# Capitalize First Letter in Brand Column
df['brand'] = df['brand'].str.title()

# %%
# Drop Missing Value in Brand Column
df['brand'] = df['brand'].replace('N/A', None)
df = df.dropna(subset=['brand'])

# %%
# Sort DataFrame by Brand
df = df.sort_values(by='brand').reset_index(drop=True)

df
# Out:
#                                           product_name              rating  \
# 0    Baseus Eli Sport 2 Open-Ear Headphones Wireles...  4.0 out of 5 stars
# 1    Baseus Inspire XP1 Adaptive Noise Cancelling E...  4.6 out of 5 stars
# 2    Baseus Eli Sport 2 Open-Ear Headphones Wireles...  4.0 out of 5 stars
# 3    Baseus Bass BP1 Pro Noise Cancelling Wireless ...  4.3 out of 5 stars
# 4    Baseus Bass BP1 NC Hybrid Active Noise Cancell...  4.6 out of 5 stars
# ..                                                 ...                 ...
# 282  XIAOMI Portable Bluetooth Speaker Bluetooth 5....  4.6 out of 5 stars
# 283  XIAOMI Redmi Watch 5 Active Smartwatch, 2.0" L...  4.6 out of 5 stars
# 284      Xiaomi Redmi Buds 4 Lite TWS Wireless Earbuds  4.1 out of 5 stars
# 285  Xiaomi Redmi Buds 4 Lite TWS Wireless Earbuds,...  4.1 out of 5 stars
# 286  XIAOMI Redmi Buds 4 Lite TWS Wireless Earbuds,...  4.2 out of 5 stars
#
#        price   brand         color ear_placement  \
# 0     $19.99  Baseus         White      Open Ear
# 1    $109.99  Baseus  Cosmic Black        In Ear
# 2     $19.99  Baseus         Green      Open Ear
# 3     $23.99  Baseus   Space Black        In Ear
# 4     $21.99  Baseus         Black        In Ear
# ..       ...     ...           ...           ...
# 282   $47.31  Xiaomi           N/A           N/A
# 283   $38.90  Xiaomi           N/A           N/A
# 284   $27.01  Xiaomi         White        In Ear
# 285   $30.06  Xiaomi         White        In Ear
# 286   $28.95  Xiaomi         Black        In Ear
#
#                                 form_factor impedance  \
# 0    Open Ear earbuds /Over the ear earbuds   16 Ohms
# 1                                    In Ear       N/A
# 2    Open Ear earbuds /Over the ear earbuds   16 Ohms
# 3                                    In Ear       N/A
# 4                                    In Ear   16 Ohms
# ..                                      ...       ...
# 282                                     N/A       N/A
# 283                                     N/A       N/A
# 284                                  In Ear   32 Ohms
# 285                                  In Ear       N/A
# 286                                  In Ear    8 Ohms
#
#                                              image_url  \
# 0    https://m.media-amazon.com/images/I/41iRmtTvb9...
# 1    https://m.media-amazon.com/images/I/51L6GgSj6p...
# 2    https://m.media-amazon.com/images/I/51MZtudDew...
# 3    https://m.media-amazon.com/images/I/51qpokZ6oO...
# 4    https://m.media-amazon.com/images/I/51RyPpxGPH...
# ..                                                 ...
# 282  https://m.media-amazon.com/images/I/8141TI0SJR...
# 283  https://m.media-amazon.com/images/I/61su9fqRFU...
# 284  https://m.media-amazon.com/images/I/41cGfxA3MH...
# 285  https://m.media-amazon.com/images/I/51-PXQ3xlD...
# 286  https://m.media-amazon.com/images/I/51T-7ztWK4...
#
#                                                reviews
# 0    [{'review': 'I've got to be honest, I'm blown ...
# 1    [{'review': 'Pretty good for the price. They s...
# 2    [{'review': 'I've got to be honest, I'm blown ...
# 3    [{'review': 'Have you ever felt the gut rumbli...
# 4    [{'review': 'The sound quality is clean, and t...
# ..                                                 ...
# 282  [{'review': 'I bought one a little over a year...
# 283  [{'review': 'Great smartwatch for the price! T...
# 284  [{'review': 'Muy buenos auriculares para escuc...
# 285  [{'review': 'no cumplió mis expectativas, sali...
# 286  [{'review': 'Cabe recalcar que la marca es bue...
#
# [287 rows x 10 columns]

# %%
# Split Product Name into Product and Feature

df[['product', 'feature']] = (
    df['product_name']
    .str.split(r',|\||\s[-–—]\s', n=1, expand=True)
)

df['product'] = df['product'].str.strip()
df['feature'] = df['feature'].fillna('N/A').str.strip()

# Drop kolom awal
df.drop(columns=['product_name'], inplace=True)

df
# Out:
#                  rating    price   brand         color ear_placement  \
# 0    4.0 out of 5 stars   $19.99  Baseus         White      Open Ear
# 1    4.6 out of 5 stars  $109.99  Baseus  Cosmic Black        In Ear
# 2    4.0 out of 5 stars   $19.99  Baseus         Green      Open Ear
# 3    4.3 out of 5 stars   $23.99  Baseus   Space Black        In Ear
# 4    4.6 out of 5 stars   $21.99  Baseus         Black        In Ear
# ..                  ...      ...     ...           ...           ...
# 282  4.6 out of 5 stars   $47.31  Xiaomi           N/A           N/A
# 283  4.6 out of 5 stars   $38.90  Xiaomi           N/A           N/A
# 284  4.1 out of 5 stars   $27.01  Xiaomi         White        In Ear
# 285  4.1 out of 5 stars   $30.06  Xiaomi         White        In Ear
# 286  4.2 out of 5 stars   $28.95  Xiaomi         Black        In Ear
#
#                                 form_factor impedance  \
# 0    Open Ear earbuds /Over the ear earbuds   16 Ohms
# 1                                    In Ear       N/A
# 2    Open Ear earbuds /Over the ear earbuds   16 Ohms
# 3                                    In Ear       N/A
# 4                                    In Ear   16 Ohms
# ..                                      ...       ...
# 282                                     N/A       N/A
# 283                                     N/A       N/A
# 284                                  In Ear   32 Ohms
# 285                                  In Ear       N/A
# 286                                  In Ear    8 Ohms
#
#                                              image_url  \
# 0    https://m.media-amazon.com/images/I/41iRmtTvb9...
# 1    https://m.media-amazon.com/images/I/51L6GgSj6p...
# 2    https://m.media-amazon.com/images/I/51MZtudDew...
# 3    https://m.media-amazon.com/images/I/51qpokZ6oO...
# 4    https://m.media-amazon.com/images/I/51RyPpxGPH...
# ..                                                 ...
# 282  https://m.media-amazon.com/images/I/8141TI0SJR...
# 283  https://m.media-amazon.com/images/I/61su9fqRFU...
# 284  https://m.media-amazon.com/images/I/41cGfxA3MH...
# 285  https://m.media-amazon.com/images/I/51-PXQ3xlD...
# 286  https://m.media-amazon.com/images/I/51T-7ztWK4...
#
#                                                reviews  \
# 0    [{'review': 'I've got to be honest, I'm blown ...
# 1    [{'review': 'Pretty good for the price. They s...
# 2    [{'review': 'I've got to be honest, I'm blown ...
# 3    [{'review': 'Have you ever felt the gut rumbli...
# 4    [{'review': 'The sound quality is clean, and t...
# ..                                                 ...
# 282  [{'review': 'I bought one a little over a year...
# 283  [{'review': 'Great smartwatch for the price! T...
# 284  [{'review': 'Muy buenos auriculares para escuc...
# 285  [{'review': 'no cumplió mis expectativas, sali...
# 286  [{'review': 'Cabe recalcar que la marca es bue...
#
#                                                product  \
# 0    Baseus Eli Sport 2 Open-Ear Headphones Wireles...
# 1    Baseus Inspire XP1 Adaptive Noise Cancelling E...
# 2    Baseus Eli Sport 2 Open-Ear Headphones Wireles...
# 3    Baseus Bass BP1 Pro Noise Cancelling Wireless ...
# 4    Baseus Bass BP1 NC Hybrid Active Noise Cancell...
# ..                                                 ...
# 282    XIAOMI Portable Bluetooth Speaker Bluetooth 5.4
# 283             XIAOMI Redmi Watch 5 Active Smartwatch
# 284      Xiaomi Redmi Buds 4 Lite TWS Wireless Earbuds
# 285      Xiaomi Redmi Buds 4 Lite TWS Wireless Earbuds
# 286      XIAOMI Redmi Buds 4 Lite TWS Wireless Earbuds
#
#                                                feature
# 0    Secure Earhook Sport Design,Ultra-Comfort,4-Mi...
# 1    Sound by Bose, Dolby Audio, Premium Real-Time ...
# 2    Secure Earhook Sport Design,Ultra-Comfort,4-Mi...
# 3    Real-Time Adaptive Noise Cancelling, Adaptive ...
# 4    12mm Super-Bass Driver, 41H Playtime, Bluetoot...
# ..                                                 ...
# 282  IP67 Wireless Speaker Waterproof with 12 Hours...
# 283  2.0" LCD Display, 18 Days of Battery Life, 140...
# 284                                                N/A
# 285  Bluetooth 5.3 Low-Latency Game Headset with AI...
# 286  Bluetooth 5.3 Low-Latency Game Headset with AI...
#
# [287 rows x 11 columns]

# %%
# Reorder columns
df = df[['product', 'feature', 'brand', 'price', 'rating', 'color', 'ear_placement', 'form_factor', 'impedance', 'image_url', 'reviews']]

df
# Out:
#                                                product  \
# 0    Baseus Eli Sport 2 Open-Ear Headphones Wireles...
# 1    Baseus Inspire XP1 Adaptive Noise Cancelling E...
# 2    Baseus Eli Sport 2 Open-Ear Headphones Wireles...
# 3    Baseus Bass BP1 Pro Noise Cancelling Wireless ...
# 4    Baseus Bass BP1 NC Hybrid Active Noise Cancell...
# ..                                                 ...
# 282    XIAOMI Portable Bluetooth Speaker Bluetooth 5.4
# 283             XIAOMI Redmi Watch 5 Active Smartwatch
# 284      Xiaomi Redmi Buds 4 Lite TWS Wireless Earbuds
# 285      Xiaomi Redmi Buds 4 Lite TWS Wireless Earbuds
# 286      XIAOMI Redmi Buds 4 Lite TWS Wireless Earbuds
#
#                                                feature   brand    price  \
# 0    Secure Earhook Sport Design,Ultra-Comfort,4-Mi...  Baseus   $19.99
# 1    Sound by Bose, Dolby Audio, Premium Real-Time ...  Baseus  $109.99
# 2    Secure Earhook Sport Design,Ultra-Comfort,4-Mi...  Baseus   $19.99
# 3    Real-Time Adaptive Noise Cancelling, Adaptive ...  Baseus   $23.99
# 4    12mm Super-Bass Driver, 41H Playtime, Bluetoot...  Baseus   $21.99
# ..                                                 ...     ...      ...
# 282  IP67 Wireless Speaker Waterproof with 12 Hours...  Xiaomi   $47.31
# 283  2.0" LCD Display, 18 Days of Battery Life, 140...  Xiaomi   $38.90
# 284                                                N/A  Xiaomi   $27.01
# 285  Bluetooth 5.3 Low-Latency Game Headset with AI...  Xiaomi   $30.06
# 286  Bluetooth 5.3 Low-Latency Game Headset with AI...  Xiaomi   $28.95
#
#                  rating         color ear_placement  \
# 0    4.0 out of 5 stars         White      Open Ear
# 1    4.6 out of 5 stars  Cosmic Black        In Ear
# 2    4.0 out of 5 stars         Green      Open Ear
# 3    4.3 out of 5 stars   Space Black        In Ear
# 4    4.6 out of 5 stars         Black        In Ear
# ..                  ...           ...           ...
# 282  4.6 out of 5 stars           N/A           N/A
# 283  4.6 out of 5 stars           N/A           N/A
# 284  4.1 out of 5 stars         White        In Ear
# 285  4.1 out of 5 stars         White        In Ear
# 286  4.2 out of 5 stars         Black        In Ear
#
#                                 form_factor impedance  \
# 0    Open Ear earbuds /Over the ear earbuds   16 Ohms
# 1                                    In Ear       N/A
# 2    Open Ear earbuds /Over the ear earbuds   16 Ohms
# 3                                    In Ear       N/A
# 4                                    In Ear   16 Ohms
# ..                                      ...       ...
# 282                                     N/A       N/A
# 283                                     N/A       N/A
# 284                                  In Ear   32 Ohms
# 285                                  In Ear       N/A
# 286                                  In Ear    8 Ohms
#
#                                              image_url  \
# 0    https://m.media-amazon.com/images/I/41iRmtTvb9...
# 1    https://m.media-amazon.com/images/I/51L6GgSj6p...
# 2    https://m.media-amazon.com/images/I/51MZtudDew...
# 3    https://m.media-amazon.com/images/I/51qpokZ6oO...
# 4    https://m.media-amazon.com/images/I/51RyPpxGPH...
# ..                                                 ...
# 282  https://m.media-amazon.com/images/I/8141TI0SJR...
# 283  https://m.media-amazon.com/images/I/61su9fqRFU...
# 284  https://m.media-amazon.com/images/I/41cGfxA3MH...
# 285  https://m.media-amazon.com/images/I/51-PXQ3xlD...
# 286  https://m.media-amazon.com/images/I/51T-7ztWK4...
#
#                                                reviews
# 0    [{'review': 'I've got to be honest, I'm blown ...
# 1    [{'review': 'Pretty good for the price. They s...
# 2    [{'review': 'I've got to be honest, I'm blown ...
# 3    [{'review': 'Have you ever felt the gut rumbli...
# 4    [{'review': 'The sound quality is clean, and t...
# ..                                                 ...
# 282  [{'review': 'I bought one a little over a year...
# 283  [{'review': 'Great smartwatch for the price! T...
# 284  [{'review': 'Muy buenos auriculares para escuc...
# 285  [{'review': 'no cumplió mis expectativas, sali...
# 286  [{'review': 'Cabe recalcar que la marca es bue...
#
# [287 rows x 11 columns]

# %%
# Change price to numeric
df['price'] = (
    df['price']
    .astype(str)
    .str.replace(r'[$,]', '', regex=True)
)

df['price'] = pd.to_numeric(df['price'], errors='coerce')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 287 entries, 0 to 286
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product        287 non-null    object
#  1   feature        287 non-null    object
#  2   brand          287 non-null    object
#  3   price          287 non-null    float64
#  4   rating         287 non-null    object
#  5   color          287 non-null    object
#  6   ear_placement  287 non-null    object
#  7   form_factor    287 non-null    object
#  8   impedance      287 non-null    object
#  9   image_url      287 non-null    object
#  10  reviews        287 non-null    object
# dtypes: float64(1), object(10)
# memory usage: 24.8+ KB

# %%
df['product'].unique()
# Out:
# array(['Baseus Eli Sport 2 Open-Ear Headphones Wireless Earbuds',
#        'Baseus Inspire XP1 Adaptive Noise Cancelling Earbuds',
#        'Baseus Bass BP1 Pro Noise Cancelling Wireless Earbuds',
#        'Baseus Bass BP1 NC Hybrid Active Noise Cancelling Wireless Earbuds',
#        'Baseus E20 True Wireless Earbuds',
#        'Baseus BS1 NC Semi-in-Ear Noise Cancelling Earbuds with Adaptive Hybrid ANC',
#        'Baseus Bass BS1 NC Semi-in-Ear True Wireless Noise Cancelling Earbuds with Adaptive Hybrid ANC',
#        'Baseus Inspire XC1 Open Ear Clip-On Earbuds',
#        'Baseus Bowie MC1 Open Ear Clip-On Earbuds',
#        'Baseus Bowie MC1 Pro Open Ear Earbuds',
#        'Baseus Bowie 30 Max Active Noise Cancelling Headphones',
#        'Baseus Bass BC1 Open Ear Earbuds Clip-On Headphones',
#        'Baseus Bowie MC1 Pro Open Ear Clip-On Headphones',
#        'Baseus Inspire XH1 Adaptive Active Noise Cancelling Headphones',
#        'Baseus Eli 2i Fit Open-Ear Headphones',
#        'Bose QuietComfort Headphones', 'Bose Ultra Open Earbuds',
#        'Bose QuietComfort Earbuds II',
#        'Bose QuietComfort Bluetooth Headphones',
#        'Bose QuietComfort II In-Ear True Wireless Earbuds',
#        'Bose QuietComfort Ultra Bluetooth Earbuds',
#        'Bose QuietComfort Ultra True Wireless Noise Cancelling In-Ear Earbuds',
#        'Bose QuietComfort Noise Cancelling Earbuds-Bluetooth Wireless Earphones',
#        'Bose New QuietComfort Ultra Earbuds (2nd Gen)',
#        'Bose QuietComfort Earbuds', 'Bose QuietComfort Bluetooth Earbuds',
#        'Bose QuietComfort Ultra Wireless Earbuds', 'Wireless Earbuds',
#        'Wireless Earbuds IPX8 Waterproof Touch Control',
#        'CMF Buds 2a Wireless Earbuds 2025 New Active Noise Cancelling 42dB Hybrid ANC Bluetooth Headphones',
#        'CMF Buds Pro 2 Wireless Earbuds with Smart Dial',
#        'Hybrid Active Noise Cancelling Ear Buds Wireless Earbuds Bluetooth Headphones with 80H Playback Wireless Charging Case & Dual LED Display Over Ear Hooks Earphones for Sports Running Gym Workout Black',
#        'HUAWEI FreeBuds 6 Earbuds', 'HUAWEI FreeBuds SE 3 Earphones',
#        'JBL Live Beam 3', 'JBL Tune 230NC TWS', 'JBL Tune Flex',
#        'JBL Quantum TWS True Wireless Noise Cancelling Gaming Earbuds',
#        'JBL Vibe Buds', 'JBL Live Pro 2', 'JBL Tune Buds 2',
#        'JBL Endurance Peak 3', 'JBL Tune Flex 2', 'JBL Endurance Race 2',
#        'JBL Vibe Beam', 'JBL Vibe Beam 2', 'JBL Endurance Race TWS',
#        'JBL Tour Pro 3', 'JBL Quantum TWS AIR', 'JBL Tune Buds',
#        'JBL Live PRO+ TWS True Wireless in-Ear Noise Cancelling Bluetooth Headphones',
#        'JBL Vibe 100 TWS True Wireless In-Ear Headphones w/Charging Case',
#        'JBL LIVE PRO+ TWS True Wireless In-ear Noise Cancelling Bluetooth Headphones',
#        'JBL Tour PRO+ TWS True Wireless Bluetooth Earbuds',
#        'JBL VIBE 100 TWS', 'JBL Quantum TWS',
#        'JBL Tune 130NC TWS True Wireless In-Ear Noise Cancelling Headphones',
#        'JLab Go Air Tones+ True Wireless Earbuds Designed with Auto On and Connect',
#        'JLab Go Air Pop+ Tones True Wireless Earbuds',
#        'JLab Go Air Pop+ True Wireless Earbuds', 'LEEMC Wireless Earbuds',
#        'Lenovo TWS Earbuds Yoga PC Edition Cosmic Blue Active Noise Cancellation Bluetooth 5.3 Wireless Earbuds ENC 3-Mic Clear Calls AI EQ Mode Switch for Gaming',
#        'Lenovo TWS Earbuds Yoga PC Edition Tidal Teal Active Noise Cancellation Bluetooth 5.3 Wireless Earbuds ENC 3-Mic Clear Calls AI EQ Mode Switch for Gaming',
#        'Monster Clarity 101 AirLinks Wireless Earbuds',
#        'Samsung Wireless Headphones Bluetooth Ear Buds for Samsung Galaxy A17 A16 A36 S25 Ultra S24 S23 S22 S21 Bluetooth 5.3 Earbuds with Mic Noise Cancelling in Ear Earphones 60H Playback with LED Display',
#        'Wireless Bluetooth 5.3 Earbuds for iPhone 17 Pro Max Air 16 Pro 16e 15 Plus Pixel 10 9 8 Pro XL 9a 8a 7 Bluetooth Headphones 60H Playback LED Power Display in Ear Earphones with Microphone for Sports',
#        'realme Buds Air 6 Pro True Wireless Earbuds',
#        'realme Buds Wireless 5 ANC in Ear Bluetooth Headphones',
#        'realme Air 6 Pro True Wireless Earbuds',
#        'realme T110 AI ENC Noise Cancelling Wireless Earbuds',
#        'realme Buds T300 Truly Wireless in-Ear Earbuds with 30dB ANC',
#        'realme Earbud T300',
#        'realme Buds T310 Truly Wireless in-Ear Earbuds with 46dB Hybrid ANC',
#        'realme Air 7 True Wireless Earbuds', 'realme Buds Air 7',
#        'Realme Air 7 True Wireless Earbuds',
#        'realme Buds Air 7 Pro with Ai Live Translation',
#        'realme Air 6 True Wireless Earbuds',
#        'SAMSUNG Galaxy Buds Pro R190 Bluetooth Earbuds True Wireless',
#        'Samsung Galaxy Buds FE True Wireless Bluetooth Earbuds',
#        'Samsung Galaxy Buds Pro True Wireless Earbud Headphones',
#        'SAMSUNG Galaxy Buds 3 Pro AI True Wireless Bluetooth Earbuds',
#        'Samsung Galaxy Buds 3 Pro AI True Wireless Bluetooth Earbuds',
#        'Samsung Galaxy Buds Core SM-R410 (2025)',
#        'SAMSUNG Galaxy Buds2 Pro True Wireless Bluetooth Earbud Headphones',
#        'Samsung Galaxy Buds 2 Pro True Wireless Bluetooth Earbuds',
#        'SAMSUNG Galaxy Buds 2 Pro True Wireless Bluetooth Earbuds',
#        'SAMSUNG Galaxy Buds3 Pro (2024',
#        'SAMSUNG Galaxy Buds 2 Pro True Wireless Bluetooth Earbuds w/ Noise Cancelling',
#        'Samsung Galaxy Buds 3 Wireless Earbud Headphones',
#        'SAMSUNG Galaxy Buds 3 FE (2025) True Wireless Bluetooth Earbuds',
#        'Samsung Galaxy Buds Fan Edition(FE) SM-R400',
#        'Sennheiser Consumer Audio MOMENTUM True Wireless 3 Earbuds -Bluetooth In-Ear Headphones for Music and Calls with ANC',
#        'Sennheiser MOMENTUM True Wireless 4 Smart Earbuds with Bluetooth 5.4',
#        'Sennheiser Momentum True Wireless 4 Smart Earbuds',
#        'Sennheiser MOMENTUM True Wireless 4 Black Copper',
#        'Sennheiser Momentum True Wireless 4 Smart Earbuds with Bluetooth 5.4',
#        'Sennheiser Consumer Audio CX Plus True Wireless Special Edition',
#        'Sennheiser ACCENTUM True Wireless Earbuds',
#        'Sennheiser ACCENTUM Open Wireless Earbuds',
#        'Sennheiser Momentum Sport',
#        'Sennheiser Accentum True Wireless In-Ear Headphones (Blue)',
#        'Sennheiser MOMENTUM True Wireless 4 Smart Earbuds',
#        'Sennheiser Consumer Audio CX True Wireless Earbuds',
#        'Sennheiser Consumer Audio MOMENTUM True Wireless 3 Earbuds -Bluetooth In-Ear Headphones for Music',
#        'Sennheiser Consumer Audio MOMENTUM True Wireless 3 Earbuds Bluetooth In-Ear Headphones for Music and Call with ANC',
#        'Sennheiser Momentum 4 Wireless Noise Cancelling Headphones',
#        'Sennheiser MOMENTUM 4 Wireless Noise Cancelling Headphones',
#        'Sennheiser Momentum True Wireless in-Ear Headphones (M3IETW/Black)',
#        'Sennheiser Consumer Audio Sport True Wireless Earbuds',
#        'for Huawei Honor 30 Pro Wireless Earbuds Bluetooth 5.3 Headphones with Charging Case',
#        'Skullcandy Dime Evo Wireless Earbuds',
#        'Skullcandy Method 360 ANC Wireless Earbuds',
#        'Sony WF-C510 Truly Wireless in-Ear Bluetooth Earbud Headphones with up to 22-Hour Battery',
#        'Soundcore P30i by Anker Noise Cancelling Earbuds',
#        'Soundcore by Anker A20i True Wireless Earbuds',
#        'Soundcore by Anker Life A1 True Wireless Earbuds',
#        'Soundcore Liberty Buds by Anker',
#        'Soundcore Liberty 4 Pro by Anker',
#        'soundcore by Anker Liberty 4 NC Wireless Noise Cancelling Earbuds',
#        'Soundcore by Anker Liberty 4 NC Noise Cancelling Earbuds',
#        'Soundcore by Anker Liberty 4 NC Wireless Earbuds',
#        'Soundcore Sleep A30 by Anker Sleep Earbuds',
#        'Soundcore P40i by Anker', 'Soundcore Sport X20 by Anker',
#        'Soundcore by Anker P20i True Wireless Earbuds',
#        'soundcore Sport X20 by Anker', 'Soundcore P31i by Anker',
#        'Soundcore by Anker Space A40 Auto-Adjustable Active Noise Cancelling Wireless Earbuds',
#        'Soundcore by Anker Space A40 Adaptive Active Noise Cancelling Wireless Earbuds',
#        'soundcore Sleep A30 by Anker Sleep Earbuds',
#        'Soundcore AeroClip by Anker',
#        'Soundcore V20i by Anker Open-Ear Headphones',
#        'soundcore by Anker Space A40 Auto-Adjustable Active Noise Cancelling Wireless Earbuds',
#        'Soundcore Select 4 Go Bluetooth Shower Speaker by Anker',
#        'Soundcore by Anker Life P2 Mini True Wireless Earbuds',
#        'TOZO Wireless Earbuds Build in Mic Clear Calls Ergonomic Light Weight Bluetooth 5.3 in Ear Headphones Waterproof Premium Stereo Sound Ear Buds 30H Playtime with 32 EQs via APP',
#        'TOZO Wireless Earbuds Bluetooth 5.3 Headphones Premium Sound Performance Touch Control LED Digital Display Wireless Charging Case Earphones Black',
#        'TOZO T10 Wireless Earbuds Bluetooth 5.3 Headphones',
#        'TWS Earbuds ENC Noise Cancellation Wireless Bluetooth Earphones',
#        'for Samsung Earbuds', 'Redmi Buds 6 Lite',
#        'Redmi Buds 6 Lite in-Ear Headphones', 'XIAOMI Redmi Buds 6 Pro',
#        'Xiaomi Redmi Buds 6 (Global Version) TWS Earphone',
#        'XIAOMI Redmi Buds 6 Dual Mic Fast Pair LDAC',
#        'Xiaomi Redmi Buds 6 Dual Mic Fast Pair LDAC',
#        'Xiaomi Redmi Buds 6 Play',
#        'XIAOMI Redmi Buds 6 Active Wireles Earbuds (Global Version)',
#        'Xiaomi Redmi Buds 6 Active Wireles Earbuds (Global Version)',
#        'XIAOMI Redmi Watch 5 Active',
#        'Xiaomi Redmi Buds 4 Lite TWS Wireless Earbuds',
#        'XIAOMI TWSEJ04LS Redmi Airdots Earphones',
#        'Xiaomi Sound Packet Mi Portable Bluetooth 5.4 Speaker',
#        'XIAOMI Redmi Buds 6 Active',
#        'Xiaomi Wireless Earbuds Redmi Buds 3 Lite',
#        'Xiaomi Redmi Buds 4 Active',
#        'Xiaomi Redmi Buds Essential Wireless Earbuds M2222E1',
#        'Xiaomi Redmi Buds 5 Pro (Global Version) Wireless Earbuds',
#        'Xiaomi Portable Mini Bluetooth Speaker Sound Pocket',
#        'XIAOMI Redmi Buds 4 Active TWS Wireless Earbuds',
#        'XIAOMI Redmi Buds 4 Active',
#        'XIAOMI Redmi Buds 5 Wireless Earphone',
#        'Xiaomi Redmi Buds 5 Wireless Earphone',
#        'XIAOMI OpenWear Stereo Hi-Res LHDC Earbuds',
#        'XIAOMI Portable Bluetooth Speaker Bluetooth 5.4',
#        'XIAOMI Redmi Watch 5 Active Smartwatch',
#        'XIAOMI Redmi Buds 4 Lite TWS Wireless Earbuds'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 287 entries, 0 to 286
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product        287 non-null    object
#  1   feature        287 non-null    object
#  2   brand          287 non-null    object
#  3   price          287 non-null    float64
#  4   rating         287 non-null    object
#  5   color          287 non-null    object
#  6   ear_placement  287 non-null    object
#  7   form_factor    287 non-null    object
#  8   impedance      287 non-null    object
#  9   image_url      287 non-null    object
#  10  reviews        287 non-null    object
# dtypes: float64(1), object(10)
# memory usage: 24.8+ KB

# %%
# Check Rating Column
df.rating.value_counts()
# Out:
# rating
# 4.2 out of 5 stars    58
# 4.4 out of 5 stars    53
# 4.3 out of 5 stars    37
# 4.0 out of 5 stars    33
# 4.1 out of 5 stars    27
# 3.8 out of 5 stars    19
# 4.6 out of 5 stars    15
# 4.5 out of 5 stars    11
# 3.7 out of 5 stars     6
# 4.7 out of 5 stars     5
# 3.6 out of 5 stars     5
# 3.9 out of 5 stars     4
# 4.8 out of 5 stars     3
# 4.9 out of 5 stars     3
# 3.2 out of 5 stars     3
# 3.5 out of 5 stars     3
# 5.0 out of 5 stars     2
# Name: count, dtype: int64

# %% [markdown]
# Rating masih bersifat object sehingga harus mengubahnya menjadi tipe data float dengan cara mengambil angka pertama saja

# %%
# Rating to numeric
df['rating'] = pd.to_numeric(
    df['rating'].astype(str).str.extract(r'(\d+\.\d+)')[0],
    errors='coerce'
)

df.rating.value_counts()
# Out:
# rating
# 4.2    58
# 4.4    53
# 4.3    37
# 4.0    33
# 4.1    27
# 3.8    19
# 4.6    15
# 4.5    11
# 3.7     6
# 4.7     5
# 3.6     5
# 3.9     4
# 4.8     3
# 4.9     3
# 3.2     3
# 3.5     3
# 5.0     2
# Name: count, dtype: int64

# %% [markdown]
# # iv. Handle Missing Value

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 287 entries, 0 to 286
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product        287 non-null    object
#  1   feature        287 non-null    object
#  2   brand          287 non-null    object
#  3   price          287 non-null    float64
#  4   rating         287 non-null    float64
#  5   color          287 non-null    object
#  6   ear_placement  287 non-null    object
#  7   form_factor    287 non-null    object
#  8   impedance      287 non-null    object
#  9   image_url      287 non-null    object
#  10  reviews        287 non-null    object
# dtypes: float64(2), object(9)
# memory usage: 24.8+ KB

# %% [markdown]
# Jika dilihat dari df.info data tidak memiliki nilai null, tetapi saat scraping jika menemukan missing value akan diubah menjadi N/A sehingga tidak terbaca sebagai missing value pada df.info. Sehingga dibutuhkan untuk mengubah nilai N/A  pada masing masing kolom menjadi nan

# %%
# Change feature 'N/A' to NaN
df['feature'] = df['feature'].replace('N/A', np.nan)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 287 entries, 0 to 286
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product        287 non-null    object
#  1   feature        276 non-null    object
#  2   brand          287 non-null    object
#  3   price          287 non-null    float64
#  4   rating         287 non-null    float64
#  5   color          287 non-null    object
#  6   ear_placement  287 non-null    object
#  7   form_factor    287 non-null    object
#  8   impedance      287 non-null    object
#  9   image_url      287 non-null    object
#  10  reviews        287 non-null    object
# dtypes: float64(2), object(9)
# memory usage: 24.8+ KB

# %%
# Change brand 'N/A' to NaN
df['brand'] = df['brand'].replace('N/A', np.nan)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 287 entries, 0 to 286
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product        287 non-null    object
#  1   feature        276 non-null    object
#  2   brand          287 non-null    object
#  3   price          287 non-null    float64
#  4   rating         287 non-null    float64
#  5   color          287 non-null    object
#  6   ear_placement  287 non-null    object
#  7   form_factor    287 non-null    object
#  8   impedance      287 non-null    object
#  9   image_url      287 non-null    object
#  10  reviews        287 non-null    object
# dtypes: float64(2), object(9)
# memory usage: 24.8+ KB

# %%
# Change color 'N/A' to NaN
df['color'] = df['color'].replace('N/A', np.nan)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 287 entries, 0 to 286
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product        287 non-null    object
#  1   feature        276 non-null    object
#  2   brand          287 non-null    object
#  3   price          287 non-null    float64
#  4   rating         287 non-null    float64
#  5   color          279 non-null    object
#  6   ear_placement  287 non-null    object
#  7   form_factor    287 non-null    object
#  8   impedance      287 non-null    object
#  9   image_url      287 non-null    object
#  10  reviews        287 non-null    object
# dtypes: float64(2), object(9)
# memory usage: 24.8+ KB

# %%
# Change ear_placement'N/A' to NaN
df['ear_placement'] = df['ear_placement'].replace('N/A', np.nan)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 287 entries, 0 to 286
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product        287 non-null    object
#  1   feature        276 non-null    object
#  2   brand          287 non-null    object
#  3   price          287 non-null    float64
#  4   rating         287 non-null    float64
#  5   color          279 non-null    object
#  6   ear_placement  278 non-null    object
#  7   form_factor    287 non-null    object
#  8   impedance      287 non-null    object
#  9   image_url      287 non-null    object
#  10  reviews        287 non-null    object
# dtypes: float64(2), object(9)
# memory usage: 24.8+ KB

# %%
# Change form_factor 'N/A' to NaN
df['form_factor'] = df['form_factor'].replace('N/A', np.nan)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 287 entries, 0 to 286
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product        287 non-null    object
#  1   feature        276 non-null    object
#  2   brand          287 non-null    object
#  3   price          287 non-null    float64
#  4   rating         287 non-null    float64
#  5   color          279 non-null    object
#  6   ear_placement  278 non-null    object
#  7   form_factor    278 non-null    object
#  8   impedance      287 non-null    object
#  9   image_url      287 non-null    object
#  10  reviews        287 non-null    object
# dtypes: float64(2), object(9)
# memory usage: 24.8+ KB

# %%
# Change impedance 'N/A' to NaN
df['impedance'] = df['impedance'].replace('N/A', np.nan)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 287 entries, 0 to 286
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product        287 non-null    object
#  1   feature        276 non-null    object
#  2   brand          287 non-null    object
#  3   price          287 non-null    float64
#  4   rating         287 non-null    float64
#  5   color          279 non-null    object
#  6   ear_placement  278 non-null    object
#  7   form_factor    278 non-null    object
#  8   impedance      203 non-null    object
#  9   image_url      287 non-null    object
#  10  reviews        287 non-null    object
# dtypes: float64(2), object(9)
# memory usage: 24.8+ KB

# %%
# Change image_url 'N/A' to NaN
df['image_url'] = df['image_url'].replace('N/A', np.nan)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 287 entries, 0 to 286
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product        287 non-null    object
#  1   feature        276 non-null    object
#  2   brand          287 non-null    object
#  3   price          287 non-null    float64
#  4   rating         287 non-null    float64
#  5   color          279 non-null    object
#  6   ear_placement  278 non-null    object
#  7   form_factor    278 non-null    object
#  8   impedance      203 non-null    object
#  9   image_url      287 non-null    object
#  10  reviews        287 non-null    object
# dtypes: float64(2), object(9)
# memory usage: 24.8+ KB

# %% [markdown]
# ## a. Imputation

# %% [markdown]
# Pada kolom price dan rating tidak memiliki null values tetapi akan tetap dilakukan handle missing value dengan imputasi menggunakan median sedangkan pada kolom feature, color, dan ear_placement akan diisi dengan nilai 'Unkown' menimbang bahwa missing value tidak terlalu banyak dan impedance akan diisi sebagai Not Specified, menjadi variable baru dikarenakan jika dilakukan dengan imputasi mode akan mempengaruhi data

# %%
# Numerik
df['price'] = df['price'].fillna(df['price'].median())
df['rating'] = df['rating'].fillna(df['rating'].median())

# Kategorikal
df['feature'] = df['feature'].fillna('Not Available')
df['color'] = df['color'].fillna('Unknown')
df['ear_placement'] = df['ear_placement'].fillna('Unknown')
df['form_factor'] = df['form_factor'].fillna(df['form_factor'].mode()[0])
df['impedance'] = df['impedance'].fillna('Not Specified')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 287 entries, 0 to 286
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product        287 non-null    object
#  1   feature        287 non-null    object
#  2   brand          287 non-null    object
#  3   price          287 non-null    float64
#  4   rating         287 non-null    float64
#  5   color          287 non-null    object
#  6   ear_placement  287 non-null    object
#  7   form_factor    287 non-null    object
#  8   impedance      287 non-null    object
#  9   image_url      287 non-null    object
#  10  reviews        287 non-null    object
# dtypes: float64(2), object(9)
# memory usage: 24.8+ KB

# %% [markdown]
# # v. Review Data Frame

# %% [markdown]
# Membuat review data frame dengan memisahkan product, brand dan reviews yang akan digunakan pada NLP model

# %%
# Explode reviews into separate rows
review_df = (
    df[['product', 'brand', 'reviews']]
    .explode('reviews')
)

review_df['review_text'] = review_df['reviews'].apply(lambda x: x['review'])
review_df['review_rating'] = review_df['reviews'].apply(lambda x: x['rating'])

review_df = review_df.drop(columns=['reviews'])

review_df
# Out:
#                                                product   brand  \
# 0    Baseus Eli Sport 2 Open-Ear Headphones Wireles...  Baseus
# 0    Baseus Eli Sport 2 Open-Ear Headphones Wireles...  Baseus
# 0    Baseus Eli Sport 2 Open-Ear Headphones Wireles...  Baseus
# 0    Baseus Eli Sport 2 Open-Ear Headphones Wireles...  Baseus
# 0    Baseus Eli Sport 2 Open-Ear Headphones Wireles...  Baseus
# ..                                                 ...     ...
# 286      XIAOMI Redmi Buds 4 Lite TWS Wireless Earbuds  Xiaomi
# 286      XIAOMI Redmi Buds 4 Lite TWS Wireless Earbuds  Xiaomi
# 286      XIAOMI Redmi Buds 4 Lite TWS Wireless Earbuds  Xiaomi
# 286      XIAOMI Redmi Buds 4 Lite TWS Wireless Earbuds  Xiaomi
# 286      XIAOMI Redmi Buds 4 Lite TWS Wireless Earbuds  Xiaomi
#
#                                            review_text       review_rating
# 0    I've got to be honest, I'm blown away by the s...  5.0 out of 5 stars
# 0    I'm a big fan of Baseus earbuds. These things ...  5.0 out of 5 stars
# 0    Product had great sound and comfort but did no...  4.0 out of 5 stars
# 0    This review is for Baseus Eli Sport 2 Open-ear...  3.0 out of 5 stars
# 0    Very reasonable. Loud and clear! I mostly wear...  5.0 out of 5 stars
# ..                                                 ...                 ...
# 286                                     Me encantaron.  5.0 out of 5 stars
# 286  La calidad del sonido está bien para el valor....  3.0 out of 5 stars
# 286        La calidad de audio es buena pero muy baja.  2.0 out of 5 stars
# 286  Fue una buena compra, los materiales son de mu...  5.0 out of 5 stars
# 286                                These worked great.  5.0 out of 5 stars
#
# [1542 rows x 4 columns]

# %%
# Check Duplicates in review_df
review_df.duplicated().sum()
# Out:
# 533

# %%
# Drop Duplicates in review_df
review_df = review_df.drop_duplicates()
review_df
# Out:
#                                                product   brand  \
# 0    Baseus Eli Sport 2 Open-Ear Headphones Wireles...  Baseus
# 0    Baseus Eli Sport 2 Open-Ear Headphones Wireles...  Baseus
# 0    Baseus Eli Sport 2 Open-Ear Headphones Wireles...  Baseus
# 0    Baseus Eli Sport 2 Open-Ear Headphones Wireles...  Baseus
# 0    Baseus Eli Sport 2 Open-Ear Headphones Wireles...  Baseus
# ..                                                 ...     ...
# 286      XIAOMI Redmi Buds 4 Lite TWS Wireless Earbuds  Xiaomi
# 286      XIAOMI Redmi Buds 4 Lite TWS Wireless Earbuds  Xiaomi
# 286      XIAOMI Redmi Buds 4 Lite TWS Wireless Earbuds  Xiaomi
# 286      XIAOMI Redmi Buds 4 Lite TWS Wireless Earbuds  Xiaomi
# 286      XIAOMI Redmi Buds 4 Lite TWS Wireless Earbuds  Xiaomi
#
#                                            review_text       review_rating
# 0    I've got to be honest, I'm blown away by the s...  5.0 out of 5 stars
# 0    I'm a big fan of Baseus earbuds. These things ...  5.0 out of 5 stars
# 0    Product had great sound and comfort but did no...  4.0 out of 5 stars
# 0    This review is for Baseus Eli Sport 2 Open-ear...  3.0 out of 5 stars
# 0    Very reasonable. Loud and clear! I mostly wear...  5.0 out of 5 stars
# ..                                                 ...                 ...
# 286                                     Me encantaron.  5.0 out of 5 stars
# 286  La calidad del sonido está bien para el valor....  3.0 out of 5 stars
# 286        La calidad de audio es buena pero muy baja.  2.0 out of 5 stars
# 286  Fue una buena compra, los materiales son de mu...  5.0 out of 5 stars
# 286                                These worked great.  5.0 out of 5 stars
#
# [1009 rows x 4 columns]

# %% [markdown]
# # vi. Saving Cleaned Data to CSV

# %%
# Save cleaned data to CSV
df.to_csv('data_cleaned.csv', index=False)

# %%
# Save review data to CSV
review_df.to_csv('review_data_cleaned.csv', index=False)
