# %% [markdown]
# # i. Introduction

# %% [markdown]
# Notebook dibuat untuk melakukan validasi data sesuai standar kualitas yang akan dijabarkan dibawah ini

# %% [markdown]
# # ii. Import Libraries

# %%
import pandas as pd
import great_expectations as ge
from great_expectations.checkpoint import SimpleCheckpoint

# %% [markdown]
# # iii. Load Data

# %%
df = pd.read_csv('data_cleaned.csv')

df.head()
# Out:
#                                              product  \
# 0  Baseus Eli Sport 2 Open-Ear Headphones Wireles...
# 1  Baseus Inspire XP1 Adaptive Noise Cancelling E...
# 2  Baseus Eli Sport 2 Open-Ear Headphones Wireles...
# 3  Baseus Bass BP1 Pro Noise Cancelling Wireless ...
# 4  Baseus Bass BP1 NC Hybrid Active Noise Cancell...
#
#                                              feature   brand   price  rating  \
# 0  Secure Earhook Sport Design,Ultra-Comfort,4-Mi...  Baseus   19.99     4.0
# 1  Sound by Bose, Dolby Audio, Premium Real-Time ...  Baseus  109.99     4.6
# 2  Secure Earhook Sport Design,Ultra-Comfort,4-Mi...  Baseus   19.99     4.0
# 3  Real-Time Adaptive Noise Cancelling, Adaptive ...  Baseus   23.99     4.3
# 4  12mm Super-Bass Driver, 41H Playtime, Bluetoot...  Baseus   21.99     4.6
#
#           color ear_placement                             form_factor  \
# 0         White      Open Ear  Open Ear earbuds /Over the ear earbuds
# 1  Cosmic Black        In Ear                                  In Ear
# 2         Green      Open Ear  Open Ear earbuds /Over the ear earbuds
# 3   Space Black        In Ear                                  In Ear
# 4         Black        In Ear                                  In Ear
#
#        impedance                                          image_url  \
# 0        16 Ohms  https://m.media-amazon.com/images/I/41iRmtTvb9...
# 1  Not Specified  https://m.media-amazon.com/images/I/51L6GgSj6p...
# 2        16 Ohms  https://m.media-amazon.com/images/I/51MZtudDew...
# 3  Not Specified  https://m.media-amazon.com/images/I/51qpokZ6oO...
# 4        16 Ohms  https://m.media-amazon.com/images/I/51RyPpxGPH...
#
#                                              reviews
# 0  [{'review': 'I\'ve got to be honest, I\'m blow...
# 1  [{'review': "Pretty good for the price. They s...
# 2  [{'review': 'I\'ve got to be honest, I\'m blow...
# 3  [{'review': 'Have you ever felt the gut rumbli...
# 4  [{'review': 'The sound quality is clean, and t...

# %%
# Load GX context
context = ge.get_context()

# Add datasource
datasource = context.sources.add_or_update_pandas(name="tws_datasource")

# Load CSV and make asset
csv_file = "data_cleaned.csv"  
asset = datasource.add_csv_asset(name="tws_asset", filepath_or_buffer=csv_file)
# Batch Request
batch_request = asset.build_batch_request()

# Expectation Suite
suite_name = "tws_suite"
suite = context.add_or_update_expectation_suite(expectation_suite_name=suite_name)

# Create Validator
validator = context.get_validator(
    batch_request=batch_request,
    expectation_suite_name=suite_name)

# %% [markdown]
# # iv. Checking Expectation

# %%
# 1. To be no null values in 'product' column

validator.expect_column_values_to_not_be_null('product')
# Out:
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# {
#   "success": true,
#   "result": {
#     "element_count": 287,
#     "unexpected_count": 0,
#     "unexpected_percent": 0.0,
#     "partial_unexpected_list": []
#   },
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }

# %%
# 2. To be exist in column 'rating'

validator.expect_column_to_exist(column='rating')
# Out:
# Calculating Metrics:   0%|          | 0/2 [00:00<?, ?it/s]
# {
#   "success": true,
#   "result": {},
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }

# %%
# 3. To be between min_value and max_value

validator.expect_column_values_to_be_between('rating', min_value=1, max_value=5)
# Out:
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# {
#   "success": true,
#   "result": {
#     "element_count": 287,
#     "unexpected_count": 0,
#     "unexpected_percent": 0.0,
#     "partial_unexpected_list": [],
#     "missing_count": 0,
#     "missing_percent": 0.0,
#     "unexpected_percent_total": 0.0,
#     "unexpected_percent_nonmissing": 0.0
#   },
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }

# %%
# 4. To be max value 5

validator.expect_column_max_to_be_between('rating', 5)
# Out:
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# {
#   "success": true,
#   "result": {
#     "observed_value": 5.0
#   },
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }

# %%
# 5. To be in type list

validator.expect_column_values_to_be_in_type_list('price', ['integer', 'float'])
# Out:
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# {
#   "success": true,
#   "result": {
#     "observed_value": "float64"
#   },
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }

# %%
# To match regex pattern

validator.expect_column_values_to_match_regex(
    'product',
    r'^[A-Za-z0-9\s\-\(\)&,\./\+]+$'
)
# Out:
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# {
#   "success": true,
#   "result": {
#     "element_count": 287,
#     "unexpected_count": 0,
#     "unexpected_percent": 0.0,
#     "partial_unexpected_list": [],
#     "missing_count": 0,
#     "missing_percent": 0.0,
#     "unexpected_percent_total": 0.0,
#     "unexpected_percent_nonmissing": 0.0
#   },
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }

# %%
# To be length between min_value and max_value
validator.expect_column_value_lengths_to_be_between(
    'product',
    min_value=5,
    max_value=200
)
# Out:
# Calculating Metrics:   0%|          | 0/9 [00:00<?, ?it/s]
# {
#   "success": true,
#   "result": {
#     "element_count": 287,
#     "unexpected_count": 0,
#     "unexpected_percent": 0.0,
#     "partial_unexpected_list": [],
#     "missing_count": 0,
#     "missing_percent": 0.0,
#     "unexpected_percent_total": 0.0,
#     "unexpected_percent_nonmissing": 0.0
#   },
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }

# %%
# To not match regex pattern
validator.expect_column_values_to_not_match_regex(
    'product',
    r'[@#$%^*_=<>|~`]'
)
# Out:
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# {
#   "success": true,
#   "result": {
#     "element_count": 287,
#     "unexpected_count": 0,
#     "unexpected_percent": 0.0,
#     "partial_unexpected_list": [],
#     "missing_count": 0,
#     "missing_percent": 0.0,
#     "unexpected_percent_total": 0.0,
#     "unexpected_percent_nonmissing": 0.0
#   },
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }

# %% [markdown]
# # v. Saving

# %%
# Save into Expectation Suite
validator.save_expectation_suite(discard_failed_expectations=False)

# %%
# Create a Checkpoint
checkpoint = SimpleCheckpoint(
    name="tws_checkpoint",
    data_context=context,
    validator=validator
)

result = checkpoint.run()
print(result)
